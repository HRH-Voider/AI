# %% [markdown]
# "What is the probability that a randomly selected movie has a popularity score over 2.0?"

# %% [markdown]
# Popularity score -> Mean -> Standard Deviation

# %%
import requests
import pandas
import random
import time
import seaborn

# %%
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhNDM5MjI2YWE5ODZhNzQ1MTRlOWQ4NmFhZjllNTIzMCIsIm5iZiI6MTc2MjE4Nzk0Ni4zMTAwMDAyLCJzdWIiOiI2OTA4ZGFhYWY0NmYyNGNkODFmOTM0ZmEiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.nQC-jRxtRhYAqjCgrs988M7_vuBn8o8GJwFGLeL0HIk"

movie_id = 339403
endpoint = f'https://api.themoviedb.org/3/movie/{movie_id}'

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "accept": "application/json"
}

# %%
hits = 0
popScores = []
for i in range(1000):
        print(f"Step: {i}", end="\r", flush=True)
        while True:
            movie_id = random.randint(2, 1250664)
            endpoint = f'https://api.themoviedb.org/3/movie/{movie_id}'
            response = requests.get(endpoint, headers=headers)
            if response.status_code == 200:
                break
        if response.json()["popularity"] > 2.0:
            hits += 1
        popScores.append(response.json()["popularity"])

p = hits/1000
seaborn.histplot(popScores)
# Out:
# Step: 418

# %% [markdown]
# The calculated theoretical Probability (assuming mean is 5 and standard dev is 2) would be 92%
